# %%
import pandas as pd
import hvplot.pandas

# %%
df = pd.read_csv("Bitcoin.csv")
df = df.set_index(pd.DatetimeIndex(df["Date"].values))
df
# Out:
#                   Date    Price  Change %
# 2011-11-28  11/28/2011      2.5      0.03
# 2011-11-29  11/29/2011      2.8      0.08
# 2011-11-30  11/30/2011      3.0      0.08
# 2011-12-01   12/1/2011      3.1      0.03
# 2011-12-02   12/2/2011      3.1      0.02
# ...                ...      ...       ...
# 2022-02-01    2/1/2022  38709.7      0.01
# 2022-02-02    2/2/2022  36890.2     -0.05
# 2022-02-03    2/3/2022  37287.8      0.01
# 2022-02-04    2/4/2022  41567.6      0.11
# 2022-02-05    2/5/2022  41400.9      0.00
#
# [3723 rows x 3 columns]

# %%
#Bitcoin Historical
btc_df = df
btc_df = btc_df.drop(columns = ["Date","Change %"],axis=1)
btc_df.head()
# Out:
#             Price
# 2011-11-28    2.5
# 2011-11-29    2.8
# 2011-11-30    3.0
# 2011-12-01    3.1
# 2011-12-02    3.1

# %%
# Plot the price action before and after the first halving event
btc_plot = btc_df.hvplot(title="Bitcoins Historical Price",
                        grid=True,xlabel='Date',ylabel='Bitcoin Price',color="black",legend="top",fontsize=12)
btc_plot
# Out:
# :Curve   [index]   (Price)

# %% [markdown]
# # First Halving Event Was On November 28 2012

# %%
#  Nov. 28, 2012,
first_halve = df.iloc[0:1097]
first_halve = first_halve.drop(columns = ["Date","Change %"],axis=1)
first_halve
# Out:
#             Price
# 2011-11-28    2.5
# 2011-11-29    2.8
# 2011-11-30    3.0
# 2011-12-01    3.1
# 2011-12-02    3.1
# ...           ...
# 2014-11-24  378.9
# 2014-11-25  376.4
# 2014-11-26  365.4
# 2014-11-27  368.8
# 2014-11-28  377.6
#
# [1097 rows x 1 columns]

# %%
# Plot the price action before and after the first halving event
first_plot = first_halve.hvplot(title="Bitcoins Price Action During/After The First Halving Event on November 28 2012",
                        grid=True,xlabel='Date',ylabel='Bitcoin Price',color="black",legend="top",fontsize=12)
first_plot
# Out:
# :Curve   [index]   (Price)

# %% [markdown]
# # Second Halving Event Was On July 9 2016

# %%
#  July 9 2016
second_halve = df.iloc[1319:2416]
second_halve = second_halve.drop(columns = ["Date","Change %"],axis=1)
second_halve
# Out:
#              Price
# 2015-07-09   269.1
# 2015-07-10   283.6
# 2015-07-11   292.0
# 2015-07-12   310.4
# 2015-07-13   290.4
# ...            ...
# 2018-07-05  6546.5
# 2018-07-06  6617.7
# 2018-07-07  6765.5
# 2018-07-08  6714.8
# 2018-07-09  6667.1
#
# [1097 rows x 1 columns]

# %%
# Plot the price action before and after the first halving event
second_plot = second_halve.hvplot(title="Bitcoins Price Action During/After The Second Halving Event on July 9 2016",
                        grid=True,xlabel='Date',ylabel='Bitcoin Price',color="black",legend="top",fontsize=12)
second_plot
# Out:
# :Curve   [index]   (Price)

# %% [markdown]
# # Third Halving Event Was On May 11 2020

# %%
#  July 9 2016
third_halve = df.iloc[2721:4000]
third_halve = third_halve.drop(columns = ["Date","Change %"],axis=1)
third_halve.tail()
# Out:
#               Price
# 2022-02-01  38709.7
# 2022-02-02  36890.2
# 2022-02-03  37287.8
# 2022-02-04  41567.6
# 2022-02-05  41400.9

# %%
# Plot the price action before and after the first halving event
third_plot = third_halve.hvplot(title="Bitcoins Price Action During/After The Third Halving Event on May 11 2020",
                        grid=True,xlabel='Date',ylabel='Bitcoin Price',color="black",legend="top",fontsize=12)
third_plot
# Out:
# :Curve   [index]   (Price)

# %%
combined = first_plot + second_plot + third_plot + btc_plot
combined
# Out:
# :Layout
#    .Curve.I   :Curve   [index]   (Price)
#    .Curve.II  :Curve   [index]   (Price)
#    .Curve.III :Curve   [index]   (Price)
#    .Curve.IV  :Curve   [index]   (Price)

# %%
first_line = first_halve.plot(kind="line", figsize = (10,5),
                  ylabel="Bitcoin Price", fontsize=10,colormap="Greens_r")

# %%
second_line = second_halve.plot(kind="line", figsize = (10,5),
                  ylabel="Bitcoin Price", fontsize=10,colormap="Greens_r")

# %%
third_line = third_halve.plot(kind="line", figsize = (10,5),
                  ylabel="Bitcoin Price", fontsize=10,colormap="Greens_r")
# Out:
# <AxesSubplot:ylabel='Bitcoin Price'>
