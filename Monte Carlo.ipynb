# %%
import pandas as pd
import hvplot.pandas
import numpy as np
import panel as pn
import plotly.express as px
pn.extension('plotly')
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and the following Panel extensions could not be properly loaded: ['plotly']. If you are loading custom extensions with pn.extension(...) ensure that this is called before any other HoloViz extension such as hvPlot or HoloViews.

# %%
daily_returns = pd.read_csv("BitcoinSP500.csv")
daily_returns = daily_returns.set_index("Date")
daily_returns = daily_returns.pct_change()
daily_returns = daily_returns.dropna()
daily_returns
# Out:
#             Bitcoin Price  S&P500 Price
# Date
# 11/29/2011       0.120000      0.002214
# 11/30/2011       0.071429      0.043315
# 12/1/2011        0.033333     -0.001909
# 12/2/2011        0.000000     -0.000241
# 12/5/2011       -0.064516      0.010287
# ...                   ...           ...
# 1/31/2022        0.019963      0.018886
# 2/1/2022         0.005483      0.006863
# 2/2/2022        -0.047004      0.009409
# 2/3/2022         0.010778     -0.024378
# 2/4/2022         0.114777      0.005159
#
# [2564 rows x 2 columns]

# %%
# Visualize distribution of Tesla percent change in closing price using a histogram plot
daily_returns["Bitcoin Price"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Visualize distribution of SP500 percent change in closing price using a histogram plot
daily_returns["S&P500 Price"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Visualize the distribution of daily returns across all stocks using a histogram plot
daily_returns.plot.hist(alpha=1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.read_csv("Bitcoin.csv",infer_datetime_format=True)
df = df.drop("Change %", axis=1)
df = df.set_index("Date")
df
# Out:
#               Price
# Date
# 11/28/2011      2.5
# 11/29/2011      2.8
# 11/30/2011      3.0
# 12/1/2011       3.1
# 12/2/2011       3.1
# ...             ...
# 2/1/2022    38709.7
# 2/2/2022    36890.2
# 2/3/2022    37287.8
# 2/4/2022    41567.6
# 2/5/2022    41400.9
#
# [3723 rows x 1 columns]

# %%
d_r = daily_returns.reset_index()
d_r
# Out:
#             Date  Bitcoin Price  S&P500 Price
# 0     11/29/2011       0.120000      0.002214
# 1     11/30/2011       0.071429      0.043315
# 2      12/1/2011       0.033333     -0.001909
# 3      12/2/2011       0.000000     -0.000241
# 4      12/5/2011      -0.064516      0.010287
# ...          ...            ...           ...
# 2559   1/31/2022       0.019963      0.018886
# 2560    2/1/2022       0.005483      0.006863
# 2561    2/2/2022      -0.047004      0.009409
# 2562    2/3/2022       0.010778     -0.024378
# 2563    2/4/2022       0.114777      0.005159
#
# [2564 rows x 3 columns]

# %%
# Create plot
plot = px.scatter(d_r, x='Date',
                y='Bitcoin Price',
                color='Bitcoin Price',
                title='Bitcoin Daily Returns')
  # Wrap Plotly object by explicitly declaring Panel pane
pn.pane.Plotly(plot)
# Out:
# Plotly(Figure)

# %%
# Create plot
plot = px.scatter(d_r, x='Date',
                y='S&P500 Price',
                color='S&P500 Price',
                title='SP500 Daily Returns')
  # Wrap Plotly object by explicitly declaring Panel pane
pn.pane.Plotly(plot)
# Out:
# Plotly(Figure)

# %%
import pandas as pd
import numpy as np
import panel as pn
import plotly.express as px
pn.extension('plotly')

# Define function to create plot
housing_transactions = pd.DataFrame({
    "years": np.random.randint(2010, 2019, 100),
    "sales": np.random.randint(53, 500, 100),
    "foreclosures": np.random.randint(10, 147, 100)}).sort_values(['years', 'sales'])

# Create plot
plot = px.scatter(housing_transactions, x='sales',
                y='foreclosures',
                color='years',
                title='Alleghany, PA Housing Transactions')

  # Create plot
plot = px.scatter(housing_transactions, x='sales',
                                        y='foreclosures',
                                        color='years',
                                        title='Alleghany, PA Housing Transactions')

  # Wrap Plotly object by explicitly declaring Panel pane
pn.pane.Plotly(plot)
# Out:
# Plotly(Figure)

# %%
#housing_transactions
df = pd.read_csv("Bitcoin.csv",infer_datetime_format=True)
df = df.drop("Change %", axis=1)
df = df.set_index("Date")
df = df.pct_change().dropna()
df
# Out:
#                Price
# Date
# 11/29/2011  0.120000
# 11/30/2011  0.071429
# 12/1/2011   0.033333
# 12/2/2011   0.000000
# 12/3/2011  -0.096774
# ...              ...
# 2/1/2022    0.005483
# 2/2/2022   -0.047004
# 2/3/2022    0.010778
# 2/4/2022    0.114777
# 2/5/2022   -0.004010
#
# [3722 rows x 1 columns]

# %%
# Create plot
plot = px.scatter(btc, x='Date',
                y='Price',
                color='Date',
                title='Bitcoin Daily Returns')
  # Wrap Plotly object by explicitly declaring Panel pane
pn.pane.Plotly(plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a471a8411992> in <module>
#       3                 y='Price',
#       4                 color='Date',
# ----> 5                 title='Bitcoin Daily Returns')
#       6   # Wrap Plotly object by explicitly declaring Panel pane
#       7 pn.pane.Plotly(plot)
#
# ...

# %%
# Create plot
plot = px.scatter(housing_transactions, x='Date',
                y='Price',
                color='Date',
                title='Alleghany, PA Housing Transactions')

  # Wrap Plotly object by explicitly declaring Panel pane
pn.pane.Plotly(plot)
